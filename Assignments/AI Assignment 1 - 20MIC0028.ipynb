# %%
#importing libraries

import numpy as np
import pandas as pd

# %% [markdown]
# #####**Task - 1:** Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation)

# %%
f1 = np.random.randint(100, size=4)
f1
# Out:
# array([29, 62, 14, 33])

# %%
f2 = np.around(np.random.rand(4), 2)
f2
# Out:
# array([0.82, 0.35, 0.71, 0.82])

# %%
f3 = np.around(np.random.rand(4)*10, 2)
f3
# Out:
# array([5.32, 9.47, 2.29, 3.45])

# %%
f4 = np.random.randint(100, size = 4)
f4
# Out:
# array([ 1, 32, 50, 23])

# %%
df = pd.DataFrame(data = [f1,f2,f3,f4])
df
# Out:
#        0      1      2      3
# 0  29.00  62.00  14.00  33.00
# 1   0.82   0.35   0.71   0.82
# 2   5.32   9.47   2.29   3.45
# 3   1.00  32.00  50.00  23.00

# %% [markdown]
# #####**Task - 2:** Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
columns = ['Random Value 1', 'Random Value 2', 'Random Value 3', 'Random Value 4']
df.columns = columns
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           29.00           62.00           14.00           33.00
# 1            0.82            0.35            0.71            0.82
# 2            5.32            9.47            2.29            3.45
# 3            1.00           32.00           50.00           23.00

# %% [markdown]
# #####**Task - 3:** Find the descriptive statistics of the 'df' dataframe.

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000         4.00000
# mean         9.035000       25.955000       16.750000        15.06750
# std         13.471574       27.466072       22.945575        15.51834
# min          0.820000        0.350000        0.710000         0.82000
# 25%          0.955000        7.190000        1.895000         2.79250
# 50%          3.160000       20.735000        8.145000        13.22500
# 75%         11.240000       39.500000       23.000000        25.50000
# max         29.000000       62.000000       50.000000        33.00000

# %% [markdown]
# #####**Task - 4:** Check for the null values in 'df' and find the data type of the columns.

# %%
df.isnull().sum()
# Out:
# Random Value 1    0
# Random Value 2    0
# Random Value 3    0
# Random Value 4    0
# dtype: int64

# %%
df.dtypes
# Out:
# Random Value 1    float64
# Random Value 2    float64
# Random Value 3    float64
# Random Value 4    float64
# dtype: object

# %% [markdown]
# #####**Task - 5:** Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
df.loc[:, 'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0           62.00           14.00
# 1            0.35            0.71
# 2            9.47            2.29
# 3           32.00           50.00

# %%
df.iloc[:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0           62.00           14.00
# 1            0.35            0.71
# 2            9.47            2.29
# 3           32.00           50.00
